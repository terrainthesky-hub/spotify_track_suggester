# %%
import os
from dotenv import load_dotenv
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials




load_dotenv()

cid = "42dd6ceb57674e5dbb3c19060624e359"
secret = "c3d90e116495444286098ff9f62c65bc"
client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager
=
client_credentials_manager)

# %%
artist_name = []
track_name = []
popularity = []
track_id = []
for i in range(50,10000,50):
    track_results = sp.search(q='year:2018', type='track', limit=50,offset=i)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
# Out:
# HTTP Error for GET to https://api.spotify.com/v1/search returned 404 due to Not found.
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\spotipy\client.py in _internal_call(self, method, url, payload, params)
#     171
# --> 172             response.raise_for_status()
#     173             results = response.json()
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 404 Client Error: Not Found for url: https://api.spotify.com/v1/search?q=year%3A2018&limit=50&offset=2000&type=track
#
# During handling of the above exception, another exception occurred:
#
# SpotifyException                          Traceback (most recent call last)
# ...

# %%
artist_name = []
track_name = []
album_name = []
popularity = []
track_id = []
artist_id = []
audio_features = []
year = []

for i in range(0,50):
    track_results = sp.search(q='year:2014', type='track', limit=50)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        artist_id.append(t['artists'][0]['id'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        album_name.append(t['album']['name'])
        year.append(2014)

for i in range(0,50):
    track_results = sp.search(q='year:2014', type='track', limit=50, offset=50)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        artist_id.append(t['artists'][0]['id'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        album_name.append(t['album']['name'])
        year.append(2014)

for i in range(0,50):
    track_results = sp.search(q='year:2014', type='track', limit=50, offset=100)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        artist_id.append(t['artists'][0]['id'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        album_name.append(t['album']['name'])
        year.append(2014)

for i in range(0,50):
    track_results = sp.search(q='year:2014', type='track', limit=50, offset=150)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        artist_id.append(t['artists'][0]['id'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        album_name.append(t['album']['name'])
        year.append(2014)

for i in range(0,50):
    track_results = sp.search(q='year:2014', type='track', limit=50, offset=200)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        artist_id.append(t['artists'][0]['id'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        album_name.append(t['album']['name'])
        year.append(2014)

for i in range(0,50):
    track_results = sp.search(q='year:2014', type='track', limit=50, offset=250)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        artist_id.append(t['artists'][0]['id'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        album_name.append(t['album']['name'])
        year.append(2014)

for i in range(0,50):
    track_results = sp.search(q='year:2014', type='track', limit=50, offset=300)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        artist_id.append(t['artists'][0]['id'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        album_name.append(t['album']['name'])
        year.append(2014)

for i in range(0,50):
    track_results = sp.search(q='year:2014', type='track', limit=50, offset=350)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        artist_id.append(t['artists'][0]['id'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        album_name.append(t['album']['name'])
        year.append(2014)

for i in range(0,50):
    track_results = sp.search(q='year:2014', type='track', limit=50, offset=400)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        artist_id.append(t['artists'][0]['id'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        album_name.append(t['album']['name'])
        year.append(2014)

for i in range(0,50):
    track_results = sp.search(q='year:2014', type='track', limit=50, offset=450)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        artist_id.append(t['artists'][0]['id'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        album_name.append(t['album']['name'])
        year.append(2014)

for i in range(0,50):
    track_results = sp.search(q='year:2015', type='track', limit=50)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        artist_id.append(t['artists'][0]['id'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        album_name.append(t['album']['name'])
        year.append(2015)

for i in range(0,50):
    track_results = sp.search(q='year:2015', type='track', limit=50, offset=50)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        artist_id.append(t['artists'][0]['id'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        album_name.append(t['album']['name'])
        year.append(2015)

for i in range(0,50):
    track_results = sp.search(q='year:2015', type='track', limit=50, offset=100)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        artist_id.append(t['artists'][0]['id'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        album_name.append(t['album']['name'])
        year.append(2015)

for i in range(0,50):
    track_results = sp.search(q='year:2015', type='track', limit=50, offset=150)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        artist_id.append(t['artists'][0]['id'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        album_name.append(t['album']['name'])
        year.append(2015)

for i in range(0,50):
    track_results = sp.search(q='year:2015', type='track', limit=50, offset=200)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        artist_id.append(t['artists'][0]['id'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        album_name.append(t['album']['name'])
        year.append(2015)

for i in range(0,50):
    track_results = sp.search(q='year:2015', type='track', limit=50, offset=250)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        artist_id.append(t['artists'][0]['id'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        album_name.append(t['album']['name'])
        year.append(2015)

for i in range(0,50):
    track_results = sp.search(q='year:2015', type='track', limit=50, offset=300)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        artist_id.append(t['artists'][0]['id'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        album_name.append(t['album']['name'])
        year.append(2015)

for i in range(0,50):
    track_results = sp.search(q='year:2015', type='track', limit=50, offset=350)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        artist_id.append(t['artists'][0]['id'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        album_name.append(t['album']['name'])
        year.append(2015)

for i in range(0,50):
    track_results = sp.search(q='year:2015', type='track', limit=50, offset=400)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        artist_id.append(t['artists'][0]['id'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        album_name.append(t['album']['name'])
        year.append(2015)

for i in range(0,50):
    track_results = sp.search(q='year:2015', type='track', limit=50, offset=450)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        artist_id.append(t['artists'][0]['id'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        album_name.append(t['album']['name'])
        year.append(2015)

for i in range(0,50):
    track_results = sp.search(q='year:2016', type='track', limit=50)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        artist_id.append(t['artists'][0]['id'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        album_name.append(t['album']['name'])
        year.append(2016)

for i in range(0,50):
    track_results = sp.search(q='year:2016', type='track', limit=50, offset=50)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        artist_id.append(t['artists'][0]['id'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        album_name.append(t['album']['name'])
        year.append(2016)

for i in range(0,50):
    track_results = sp.search(q='year:2016', type='track', limit=50, offset=100)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        artist_id.append(t['artists'][0]['id'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        album_name.append(t['album']['name'])
        year.append(2016)

for i in range(0,50):
    track_results = sp.search(q='year:2016', type='track', limit=50, offset=150)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        artist_id.append(t['artists'][0]['id'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        album_name.append(t['album']['name'])
        year.append(2016)

for i in range(0,50):
    track_results = sp.search(q='year:2016', type='track', limit=50, offset=200)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        artist_id.append(t['artists'][0]['id'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        album_name.append(t['album']['name'])
        year.append(2016)

for i in range(0,10000,50):
    track_results = sp.search(q='year:2016', type='track', limit=50, offset=250)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        artist_id.append(t['artists'][0]['id'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        album_name.append(t['album']['name'])
        year.append(2016)

for i in range(0,50):
    track_results = sp.search(q='year:2016', type='track', limit=50, offset=300)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        artist_id.append(t['artists'][0]['id'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        album_name.append(t['album']['name'])
        year.append(2016)

for i in range(0,50):
    track_results = sp.search(q='year:2016', type='track', limit=50, offset=350)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        artist_id.append(t['artists'][0]['id'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        album_name.append(t['album']['name'])
        year.append(2016)

for i in range(0,50):
    track_results = sp.search(q='year:2016', type='track', limit=50, offset=400)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        artist_id.append(t['artists'][0]['id'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        album_name.append(t['album']['name'])
        year.append(2016)

for i in range(0,50):
    track_results = sp.search(q='year:2016', type='track', limit=50, offset=450)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        artist_id.append(t['artists'][0]['id'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        album_name.append(t['album']['name'])
        year.append(2016)

for i in range(0,50):
    track_results = sp.search(q='year:2017', type='track', limit=50)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        artist_id.append(t['artists'][0]['id'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        album_name.append(t['album']['name'])
        year.append(2017)

for i in range(0,50):
    track_results = sp.search(q='year:2017', type='track', limit=50, offset=50)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        artist_id.append(t['artists'][0]['id'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        album_name.append(t['album']['name'])
        year.append(2017)

for i in range(0,50):
    track_results = sp.search(q='year:2017', type='track', limit=50, offset=100)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        artist_id.append(t['artists'][0]['id'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        album_name.append(t['album']['name'])
        year.append(2017)

for i in range(0,50):
    track_results = sp.search(q='year:2017', type='track', limit=50, offset=150)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        artist_id.append(t['artists'][0]['id'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        album_name.append(t['album']['name'])
        year.append(2017)

for i in range(0,50):
    track_results = sp.search(q='year:2017', type='track', limit=50, offset=200)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        artist_id.append(t['artists'][0]['id'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        album_name.append(t['album']['name'])
        year.append(2017)

for i in range(0,50):
    track_results = sp.search(q='year:2017', type='track', limit=50, offset=250)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        artist_id.append(t['artists'][0]['id'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        album_name.append(t['album']['name'])
        year.append(2017)

for i in range(0,50):
    track_results = sp.search(q='year:2017', type='track', limit=50, offset=300)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        artist_id.append(t['artists'][0]['id'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        album_name.append(t['album']['name'])
        year.append(2017)

for i in range(0,50):
    track_results = sp.search(q='year:2017', type='track', limit=50, offset=350)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        artist_id.append(t['artists'][0]['id'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        album_name.append(t['album']['name'])
        year.append(2017)

for i in range(0,50):
    track_results = sp.search(q='year:2017', type='track', limit=50, offset=400)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        artist_id.append(t['artists'][0]['id'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        album_name.append(t['album']['name'])
        year.append(2017)

for i in range(0,50):
    track_results = sp.search(q='year:2017', type='track', limit=50, offset=450)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        artist_id.append(t['artists'][0]['id'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        album_name.append(t['album']['name'])
        year.append(2017)

for i in range(0,50):
    track_results = sp.search(q='year:2018', type='track', limit=50)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        artist_id.append(t['artists'][0]['id'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        album_name.append(t['album']['name'])
        year.append(2018)

for i in range(0,50):
    track_results = sp.search(q='year:2018', type='track', limit=50, offset=50)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        artist_id.append(t['artists'][0]['id'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        album_name.append(t['album']['name'])
        year.append(2018)

for i in range(0,50):
    track_results = sp.search(q='year:2018', type='track', limit=50, offset=100)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        artist_id.append(t['artists'][0]['id'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        album_name.append(t['album']['name'])
        year.append(2018)

for i in range(0,50):
    track_results = sp.search(q='year:2018', type='track', limit=50, offset=150)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        artist_id.append(t['artists'][0]['id'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        album_name.append(t['album']['name'])
        year.append(2018)

for i in range(0,50):
    track_results = sp.search(q='year:2018', type='track', limit=50, offset=200)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        artist_id.append(t['artists'][0]['id'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        album_name.append(t['album']['name'])
        year.append(2018)

for i in range(0,50):
    track_results = sp.search(q='year:2018', type='track', limit=50, offset=250)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        artist_id.append(t['artists'][0]['id'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        album_name.append(t['album']['name'])
        year.append(2018)

for i in range(0,50):
    track_results = sp.search(q='year:2018', type='track', limit=50, offset=300)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        artist_id.append(t['artists'][0]['id'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        album_name.append(t['album']['name'])
        year.append(2018)

for i in range(0,50):
    track_results = sp.search(q='year:2018', type='track', limit=50, offset=350)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        artist_id.append(t['artists'][0]['id'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        album_name.append(t['album']['name'])
        year.append(2018)

for i in range(0,50):
    track_results = sp.search(q='year:2018', type='track', limit=50, offset=400)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        artist_id.append(t['artists'][0]['id'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        album_name.append(t['album']['name'])
        year.append(2018)

for i in range(0,50):
    track_results = sp.search(q='year:2018', type='track', limit=50, offset=450)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        artist_id.append(t['artists'][0]['id'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        album_name.append(t['album']['name'])
        year.append(2018)

for i in range(0,50):
    track_results = sp.search(q='year:2019', type='track', limit=50)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        artist_id.append(t['artists'][0]['id'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        album_name.append(t['album']['name'])
        year.append(2019)

for i in range(0,50):
    track_results = sp.search(q='year:2019', type='track', limit=50, offset=50)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        artist_id.append(t['artists'][0]['id'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        album_name.append(t['album']['name'])
        year.append(2019)

for i in range(0,50):
    track_results = sp.search(q='year:2019', type='track', limit=50, offset=100)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        artist_id.append(t['artists'][0]['id'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        album_name.append(t['album']['name'])
        year.append(2019)

for i in range(0,50):
    track_results = sp.search(q='year:2019', type='track', limit=50, offset=150)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        artist_id.append(t['artists'][0]['id'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        album_name.append(t['album']['name'])
        year.append(2019)

for i in range(0,50):
    track_results = sp.search(q='year:2019', type='track', limit=50, offset=200)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        artist_id.append(t['artists'][0]['id'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        album_name.append(t['album']['name'])
        year.append(2019)

for i in range(0,50):
    track_results = sp.search(q='year:2019', type='track', limit=50, offset=250)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        artist_id.append(t['artists'][0]['id'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        album_name.append(t['album']['name'])
        year.append(2019)

for i in range(0,50):
    track_results = sp.search(q='year:2019', type='track', limit=50, offset=300)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        artist_id.append(t['artists'][0]['id'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        album_name.append(t['album']['name'])
        year.append(2019)

for i in range(0,50):
    track_results = sp.search(q='year:2019', type='track', limit=50, offset=350)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        artist_id.append(t['artists'][0]['id'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        album_name.append(t['album']['name'])
        year.append(2019)

for i in range(0,50):
    track_results = sp.search(q='year:2019', type='track', limit=50, offset=400)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        artist_id.append(t['artists'][0]['id'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        album_name.append(t['album']['name'])
        year.append(2019)

for i in range(0,50):
    track_results = sp.search(q='year:2019', type='track', limit=50, offset=450)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        artist_id.append(t['artists'][0]['id'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        album_name.append(t['album']['name'])
        year.append(2019)

# %%
from web_app.models import Tracks

# %%
for x in range(0, 2500):
    track_records = Track(artist_name=artist_name[x], track_name=track_name[x], album_name=album_name[x], track_id=track_id[x], artist_id=artist_id[x], year=year[x], danceability=audiofeatures[x][0]['danceability'], energy=audiofeatures[x][0]['energy'], key=audiofeatures[x][0]['key'], loudness=audiofeatures[x][0]['loudness'], mode=audiofeatures[x][0]['mode'], speechiness=audiofeatures[x][0]['speechiness'], acousticness=audiofeatures[x][0]['acousticness'], instrumentalness=audiofeatures[x][0]['instrumentalness'], liveness=audiofeatures[x][0]['liveness'], valence=audiofeatures[x][0]['valence'], tempo=audiofeatures[x][0]['tempo'], duration_ms=audiofeatures[x][0]['duration_ms'], time_signature=audiofeatures[x][0]['time_signature'])

# %%
for x in range(0, 50):
    print(artist_name[x])
# Out:
# 5 Seconds of Summer
# Juice WRLD
# Alec Benjamin
# Kodak Black
# Juice WRLD
# Future
# The Weeknd
# benny blanco
# Summer Walker
# Cardi B
# Roddy Ricch
# Travis Scott
# Zedd
# Playboi Carti
# Sheck Wes
# A Boogie Wit da Hoodie
# Joji
# 6ix9ine
# Post Malone
# Bazzi
# Drake
# Metro Boomin
# Jordan Davis
# Ava Max
# Lady Gaga
# Juice WRLD
# Drake
# Dan + Shay
# Lil Baby
# Alec Benjamin
# Mac Miller
# RL Grime
# Morgan Wallen
# Dean Lewis
# Calum Scott
# Calum Scott
# Earth, Wind & Fire
# Ariana Grande
# Metro Boomin
# Trippie Redd
# The Chainsmokers
# Aminé
# Cardi B
# Post Malone
# Morgan Wallen
# Lauren Daigle
# Chris Lane
# Kina
# City Girls
# Ski Mask The Slump God

# %%
for x in range(50, 100):
    print(artist_name[x])
# Out:
# 5 Seconds of Summer
# Juice WRLD
# Alec Benjamin
# Kodak Black
# Juice WRLD
# Future
# The Weeknd
# benny blanco
# Summer Walker
# Cardi B
# Roddy Ricch
# Travis Scott
# Zedd
# Playboi Carti
# Sheck Wes
# A Boogie Wit da Hoodie
# Joji
# 6ix9ine
# Post Malone
# Bazzi
# Drake
# Metro Boomin
# Jordan Davis
# Ava Max
# Lady Gaga
# Juice WRLD
# Drake
# Dan + Shay
# Lil Baby
# Alec Benjamin
# Mac Miller
# RL Grime
# Morgan Wallen
# Dean Lewis
# Calum Scott
# Calum Scott
# Earth, Wind & Fire
# Ariana Grande
# Metro Boomin
# Trippie Redd
# The Chainsmokers
# Aminé
# Cardi B
# Post Malone
# Morgan Wallen
# Lauren Daigle
# Chris Lane
# Kina
# City Girls
# Ski Mask The Slump God

# %%
track_results['tracks']['items'][49]
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6LuN9FCkKOj5PcnpouEgny'},
#     'href': 'https://api.spotify.com/v1/artists/6LuN9FCkKOj5PcnpouEgny',
#     'id': '6LuN9FCkKOj5PcnpouEgny',
#     'name': 'Khalid',
#     'type': 'artist',
#     'uri': 'spotify:artist:6LuN9FCkKOj5PcnpouEgny'}],
#   'available_markets': ['AE',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'KW',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
# ...

# %%
for x in range(0, 10000):
    audio_features.append(sp.audio_features(track_id[x]))

# %%
audio_features[9999][0]['danceability']
# Out:
# 0.596

# %%
sp.audio_features(track_id[0])
# Out:
# [{'danceability': 0.784,
#   'energy': 0.43,
#   'key': 10,
#   'loudness': -8.756,
#   'mode': 0,
#   'speechiness': 0.0364,
#   'acousticness': 0.123,
#   'instrumentalness': 0,
#   'liveness': 0.0887,
#   'valence': 0.236,
#   'tempo': 127.087,
#   'type': 'audio_features',
#   'id': '4TnjEaWOeW0eKTKIEvJyCa',
#   'uri': 'spotify:track:4TnjEaWOeW0eKTKIEvJyCa',
#   'track_href': 'https://api.spotify.com/v1/tracks/4TnjEaWOeW0eKTKIEvJyCa',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4TnjEaWOeW0eKTKIEvJyCa',
#   'duration_ms': 159382,
#   'time_signature': 4}]

# %%
import pandas as pd
track_dataframe = pd.DataFrame({'artist_name' : artist_name, 'artist_id': artist_id, 'track_name' : track_name, 'track_id' : track_id, 'popularity' : popularity})
print(track_dataframe.shape)
track_dataframe.head()

# %%
track_results['tracks']['items'][1]['artists'][0]['name']
